// %%
---
title: Entity Actions
--- 
flowchart TB
    pt[Patron]--registers for-->ac[Account]
    pt--logs in to-->ac
    pt--logs out of-->ac
    pt--changes password for-->ac
    ad[Admin]--registers for-->ac[Account]
    ad--logs in to-->ac
    ad--logs out of-->ac
    ad--changes password for-->ac
    pt--browses-->catalog
    ad--browses-->catalog
    ad--creates-->ck[Checkout]
    ad--closes-->ck
    pt--places-->hd[Hold]
    pt--removes-->hd
    pt--"(of non-junior cardholdertype) pays"-->uf[UnpaidFine]
    ck[Checkout]--generates zero or one when closed-->uf
    pt--views-->ps[PatronSummary aggregate]
