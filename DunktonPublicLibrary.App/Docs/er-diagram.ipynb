// %%
---
title: Entity Relationships
---

flowchart TB
    lb[Library]--has one or many-->ad[Admin]--has one-->lb
    lb--has one or many-->pt[Patron]--has one-->lb
    pt--has one-->ch[CardholderType]--has one or many-->pt
    lb--has one or many-->ct[Catalog]--has one-->lb
    ct--has one or many-->mt["Material (ICatalogable)"]
    ct--has one or many-->ch--has one or many-->ct
    bk[Book]--has one-->ct
    bk--is a-->mt
    mg[Magazine]--has one-->ct
    mg--is a -->mt
    vc[VideoCassette]--has one-->ct
    vc--is a-->mt
    lb--has zero or many-->ck[Checkout]--has one-->lb
    ck--has one-->pt--has zero or many-->ck
    ck--has one-->ad--has zero or many-->ck
    ck--has one-->mt
    lb--has zero or many-->hd[Hold]--has one-->lb
    hd--has one-->mt
    hd--has one-->pt--has zero or many-->hd
    lb--has zero or many-->uf[UnpaidFine]--has one-->lb
    uf--has one-->pt--has zero or many-->uf
    lb--has zero or many-->cy[CheckoutHistory]--has one-->lb
    lb--has zero or many-->fh[FineHistory]--has one-->lb
    ad--has one-->ac[Account]--has zero or one-->ad
    pt--has one-->ac--has zero or one-->pt
